# %% [markdown]
# # NAME: MELVIN OPPONG-TACHIE
# # INDEX NUMBER: 11116605
# # CLASS: BMEN

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
dataset = pd.read_csv('red_wine.csv')

# %%
dataset
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
dataset.head(10)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
# 5            7.4              0.66         0.00             1.8      0.075
# 6            7.9              0.60         0.06             1.6        NaN
# 7            7.3              0.65         0.00             1.2      0.065
# 8            7.8              0.58         0.02             2.0      0.073
# 9            7.5              0.50         0.36             6.1      0.071
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# ...

# %%
dataset.tail(20)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1579            6.2             0.560         0.09             1.7      0.053
# 1580            7.4             0.350         0.33             2.4      0.068
# 1581            6.2             0.560         0.09             1.7      0.053
# 1582            6.1             0.715         0.10             2.6      0.053
# 1583            6.2             0.460         0.29             2.1      0.074
# 1584            6.7             0.320         0.44             2.4      0.061
# 1585            7.2             0.390         0.44             2.6      0.066
# 1586            7.5             0.310         0.41             2.4      0.065
# 1587            5.8             0.610         0.11             1.8      0.066
# 1588            7.2             0.660         0.33             2.5      0.068
# 1589            6.6             0.725         0.20             7.8      0.073
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1598 non-null   float64
#  1   volatile acidity      1598 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1595 non-null   float64
#  5   free sulfur dioxide   1598 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1598 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1598 non-null   float64
# dtypes: float64(12)
# memory usage: 150.0 KB

# %%
dataset.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1598.000000       1598.000000  1599.000000     1599.000000
# mean        8.318335          0.527747     0.270976        2.538806
# std         1.740863          0.179092     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1595.000000          1598.000000           1599.000000  1598.000000
# mean      0.087476            15.867334             46.467792     0.996746
# std       0.047117            10.459029             32.895324     0.001887
# ...

# %%
# Shape of dataset 
dataset.shape
# Out:
# (1599, 12)

# %%
# Correlation matrix of dataset
dataset.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.255282     0.671371
# volatile acidity          -0.255282          1.000000    -0.552334
# citric acid                0.671371         -0.552334     1.000000
# residual sugar             0.114743          0.002075     0.143577
# chlorides                  0.093866          0.061107     0.203944
# free sulfur dioxide       -0.153762         -0.010496    -0.061884
# total sulfur dioxide      -0.112632          0.076881     0.035533
# density                    0.667799          0.021796     0.365370
# pH                        -0.683021          0.234801    -0.541904
# sulphates                  0.183213         -0.260870     0.312770
# alcohol                   -0.061062         -0.202097     0.109903
# quality                    0.124639         -0.390721     0.226166
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %%
# Number of missing values in each column 
dataset.isnull().sum()
# Out:
# fixed acidity           1
# volatile acidity        1
# citric acid             0
# residual sugar          0
# chlorides               4
# free sulfur dioxide     1
# total sulfur dioxide    0
# density                 1
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 1
# dtype: int64

# %%
# Number of unique values in each column of dataset 
dataset.nunique()
# Out:
# fixed acidity            96
# volatile acidity        143
# citric acid              80
# residual sugar           91
# chlorides               153
# free sulfur dioxide      60
# total sulfur dioxide    144
# density                 436
# pH                       89
# sulphates                96
# alcohol                  65
# quality                   6
# dtype: int64

# %%
# Percentage of each quality value in dataset
(dataset["quality"].value_counts(normalize=True) * 100).round(2).astype(str) + '%'
# Out:
# quality
# 5.0    42.62%
# 6.0    39.86%
# 7.0    12.45%
# 4.0     3.32%
# 8.0     1.13%
# 3.0     0.63%
# Name: proportion, dtype: object

# %%
dataset.hist(figsize=(14, 12), bins=20, edgecolor='black')
plt.suptitle('Histograms: Distribution of Each Property in the Dataset')
plt.show()

# %%
fig, axes = plt.subplots(nrows=4, ncols=3, figsize=(15, 10))
fig.suptitle('Scatter Plots: Wine Samples And Their Ingredients')

axes = axes.flatten()

colors = ['darkorange', 'blue', 'green', 'red', 'purple', 'brown', 'yellow', 'gray', 'olive', 'teal', 'magenta', 'salmon']

for i, col in enumerate(dataset.columns[:]): 
    axes[i].scatter(dataset.index, dataset[col], color=colors[i], alpha=0.5, label=col)
    axes[i].set_title(col)
    axes[i].set_xlabel('Wine Samples')
    axes[i].set_ylabel(col)
    axes[i].legend()
                    
plt.tight_layout(rect=[0, 0, 1, 0.96])

plt.show()

# %%
fig, axes = plt.subplots(nrows=4, ncols=3, figsize=(15, 10))
fig.suptitle('Box Plots: Ingredients Against Wine Quality')

axes = axes.flatten()

for i, col in enumerate(dataset.columns[:-1]): 
    if i < len(axes) - 1:  
        box_colors = plt.cm.viridis(np.linspace(0, 1, len(sorted(dataset['quality'].unique()))))
        box_plot = axes[i].boxplot([dataset[col][dataset['quality'] == q] for q in sorted(dataset['quality'].unique())], patch_artist=True)

        for patch, color in zip(box_plot['boxes'], box_colors):
            patch.set_facecolor(color)

        axes[i].set_title(col)
        axes[i].set_xticklabels(sorted(dataset['quality'].unique()))
        axes[i].set_xlabel('Quality')
        axes[i].set_ylabel(col)

plt.tight_layout(rect=[0, 0, 1, 0.96])

fig.delaxes(axes[-1])

plt.show()

# %%
plt.hist(dataset['fixed acidity'], bins = 20, edgecolor = 'black')
plt.xlabel('Fixed Acidity')
plt.ylabel('Frequency')
plt.title('Distribution of Fixed Acidity')
plt.show()

# %%
quality_counts = dataset['quality'].value_counts()
plt.pie(quality_counts, labels=quality_counts.index, autopct='%1.1f%%', colors=['lightcoral', 'gold', 'lightgreen', 'skyblue', 'purple', 'orange'])
plt.title('Proportion of Quality Ratings')
plt.show()

# %%
plt.scatter(dataset['volatile acidity'], dataset['citric acid'], c='green', alpha=0.5)
plt.title('Volatile Acidity vs Citric Acid')
plt.xlabel('Volatile Acidity')
plt.ylabel('Citric Acid')
plt.show()

# %%
plt.figure(figsize=(8, 6))
plt.title('Correlation Heatmap')
plt.imshow(dataset.corr(), cmap='coolwarm', interpolation='none')
plt.colorbar()
plt.xticks(range(len(dataset.corr().columns)), dataset.corr().columns, rotation=90)
plt.yticks(range(len(dataset.corr().columns)), dataset.corr().columns)
plt.show()

# %% [markdown]
#  # Wine Analysis Report
# ## __Introduction__
# ---
# This report gives information about the various properties or ingredients of wine samples, with results from diverse skills and techniques such as pie charts, scatter plots, heatmaps, histograms, scatter plots, box plots, and histograms. By examining the distribution of quality ratings, correlations between ingredients, and variations across quality levels, valuable insights are obtained the characteristics of the dataset.
#
# ### *Pie Chart Analysis (Proportion of Quality Ratings)*
# The pie chart depicts the distribution of quality ratings for wine samples. Notably, 5.0 dominates at 42.6%, followed closely by 6.0 at 39.9%. Rare ratings include 3.0 (0.6%) and 8.0 (1.1%). Ratings 4.0 and 7.0 stand at 3.3% and 12.7%, respectively.
#
# ### *Scatter Plot Analysis (Volatile Acidity vs Citric Acidity)*
# The scatter plot shows a negative correlation between volatile acidity and citric acid, indicating a robust negative linear relationship.Heatmap AnalysisThe correlation heatmap showcases strong positive/negative correlations between variables. Alcohol correlates positively with quality (0.5) but negatively with density (-0.7). Citric acid positively correlates with quality (0.2), while pH has a negative correlation with fixed acidity (-0.7).
#
# ### *Histogram Analysis (Distribution of Fixed Acidity)*
# The histogram also depicts that the distribution of fixed acidity is not even, but rather tilted to the right. This means that there are more wines with low fixed acidity than high fixed acidity, and that the wines with very high fixed acidity are not common.
#
# ### *Analysis of Scatter Plots (Wine Samples and Their Ingredients)*
# The scatter plots highlight key ingredient distributions. Fixed acidity is right-skewed (values from 6-8), volatile acidity slightly right-skewed (0.2-0.6), citric acid bimodal (peaks at 0 and 0.5), residual sugar highly right-skewed (values from 1-3). Chloride and free sulfur dioxide are highly right-skewed (values from 0.05-0.1, 5-25). Total sulfur dioxide is also right-skewed (values from 20-80). Density is slightly left-skewed (values from 0.995-1). pH is normally distributed (values from 3-3.5), sulphate right-skewed (values from 0.5-0.8). Alcohol is bimodal (peaks at 9 and 11), and quality is normally distributed (values from 5-6).
#
# ### *Analysis of Box Plots (Ingredients Against Wine Quality)*
# Box plots provide insights into ingredient variations across quality levels. Fixed acidity lacks variation, while volatile acidity, citric acid, and alcohol show clear trends correlating with quality. Residual sugar, chloride, and free sulfur dioxide show minimal variation.
#
# ### *Analysis of Histograms (Distribution of Each Property in Dataset)*
# The histograms depict left-skewed quality ratings, indicating predominantly medium to low quality wines. Alcohol content is right-skewed, with most samples falling in the low to medium range. Fixed acidity and citric acid are approximately normally distributed. Volatile acidity, residual sugar, chlorides, free sulfur dioxide, total sulfur dioxide, density, and pH exhibit positive skewness, with most samples having lower values.
#
# ## __Conclusion__
# ---
# In conclusion, this report reveals patterns and relationships within the red wine dataset. Properties such as volatile acidity, citric acid, and alcohol content tend to greatly influence the quality of red wine. The insights obtained from the analysis and also stated in this report can help to guide subsequent processes in the preparation of red wine to enhance the overall quality.
